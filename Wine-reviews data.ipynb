# %% [markdown]
# I took the wine reviews dataset from https://www.kaggle.com/zynicide/wine-reviews

# %%
#import dataset
import pandas as pd

# %%
wine = pd.read_csv('winemag-data-130k-v2.csv')

# %%
wine.head(3)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
#
#     designation  points  price           province           region_1  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1      Avidagos      87   15.0              Douro                NaN
# 2           NaN      87   14.0             Oregon  Willamette Valley
#
#             region_2    taster_name taster_twitter_handle  \
# 0                NaN  Kerin O’Keefe          @kerinokeefe
# 1                NaN     Roger Voss            @vossroger
# 2  Willamette Valley   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
wine = wine.drop('Unnamed: 0', axis = 1)

# %%
wine
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
#figure out all the unigue varieties of wine
variety = wine.variety.unique()

# %%
variety
# Out:
# array(['White Blend', 'Portuguese Red', 'Pinot Gris', 'Riesling',
#        'Pinot Noir', 'Tempranillo-Merlot', 'Frappato', 'Gewürztraminer',
#        'Cabernet Sauvignon', 'Nerello Mascalese', 'Chardonnay', 'Malbec',
#        'Tempranillo Blend', 'Meritage', 'Red Blend', 'Merlot',
#        "Nero d'Avola", 'Chenin Blanc', 'Gamay', 'Sauvignon Blanc',
#        'Viognier-Chardonnay', 'Primitivo', 'Catarratto', 'Inzolia',
#        'Petit Verdot', 'Monica', 'Bordeaux-style White Blend', 'Grillo',
#        'Sangiovese', 'Cabernet Franc', 'Champagne Blend',
#        'Bordeaux-style Red Blend', 'Aglianico', 'Petite Sirah',
#        'Touriga Nacional', 'Carmenère', 'Albariño', 'Petit Manseng',
#        'Rosé', 'Zinfandel', 'Vernaccia', 'Rosato', 'Grüner Veltliner',
#        'Viognier', 'Vermentino', 'Grenache Blanc', 'Syrah', 'Nebbiolo',
#        'Shiraz-Cabernet Sauvignon', 'Pinot Blanc', 'Alsace white blend',
#        'Barbera', 'Rhône-style Red Blend', 'Portuguese White', 'Graciano',
# ...

# %%
len(variety)
# Out:
# 708

# %%
#to get this I manually went thru the list and copied everything that wasn't a grape verietal 
# i deciced that this was too time consuming so I scrapped this part
nongrapes = ['White Blend', 'Portuguese Red','Red Blend', 'Champagne Blend', 'Rosé','G-S-M', 'Rosato', 'Portuguese White',
# Out:
#   File "<ipython-input-11-656e8baaa798>", line 3
#     nongrapes = ['White Blend', 'Portuguese Red','Red Blend', 'Champagne Blend', 'Rosé','G-S-M', 'Rosato', 'Portuguese White',
#                                                                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
#wine verietals by country, also blends by contry (eg 'Bordeaux-style blend' was assumed to only have french grapes and thus put in with the french verietals)
#Also if blends have grapes from more then one country, they are in the list of the country from the first grape
france = ['Pinot Gris','Pinot Noir','Cabernet Sauvignon', 'Bordeaux-style Red Blend', 'Shiraz', 'Pinot Bianco', 'Fumé Blanc', 'Rhône-style Red Blend','Sauvignon','Tannat-Cabernet', 'Bordeaux-style White Blend', 'Shiraz-Cabernet Sauvignon', 'Pinot Blanc', 'Alsace white blend','Syrah', 'Petit Manseng', 'Carmenère', 'Petite Sirah', 'Chardonnay', 'Cabernet Franc', 'Malbec', 'Meritage', 'Merlot', 'Gamay','Petit Verdot', 'Sauvignon Blanc', 'Viognier-Chardonnay',  ]
germany = ['Riesling','Gewürztraminer', ]
spain = ['Tempranillo-Merlot', 'Tempranillo Blend', 'Monica', 'Verdejo', 'Albariño', 'Grenache Blanc', 'Graciano', ]
italy = ['Frappato', 'Nerello Mascalese', 'Montepulciano','Moscato', "Nero d'Avola",'Sangiovese Grosso','Bonarda','Prugnolo Gentile', 'Catarratto','Barbera', 'Inzolia', 'Grillo', 'Nebbiolo', 'Vermentino', 'Sangiovese', 'Vernaccia']
croatia = ['Primitivo', 'Zinfandel', 'Viognier', ]
greece = ['Aglianico', ]
portugal = ['Touriga Nacional']
austria = ['Grüner Veltliner']
argentina = ['Torrontés']
hungary = ['Furmint']

# %% [markdown]
# Going thru this manually was going to take too much time so I stopped filling in these lists and I scraped Wikipeadia for a list of grapes and their country of origin

# %%
#import grapes from wiki
grapes = pd.read_csv('grapes/grapes.csv')

# %%
grapes.head()
# Out:
#   Common Name(s)                                       All Synonyms  \
# 0        Abbuoto                                     Aboto, Cecubo.
# 1       Abouriou  Beaujolais, Early Burgunder, Early Burgundy, G...
# 2  Alexandroouli  Aleksandroouly, Aleksandrouli, Aleksandrouli s...
# 3      Akhasheni                                        Akhashenuli
# 4        Abrusco  Abrostalo, Abrostine, Abrostino, Abrusco nero,...
#
#         Country of origin                                           Pedigree  \
# 0            Italy, Lazio                                                NaN
# 1       France, Southwest  Potential (not yet confirmed) parent is Magdel...
# 2                 Georgia                                                NaN
# 3  Georgia Eastern parts.                                                NaN
# 4          Italy, Tuscany                                                NaN
#
#   Hectares cultivated (Year) Year of introduction
# ...

# %%
grapes1 = pd.read_csv('grapes/grapes_1.csv')

# %%
grapes1.head()
# Out:
#              Common Name(s)  \
# 0                 Adalmiina
# 1                  Addoraca
# 2  Aidani / Aidini / Aedani
# 3                     Airén
# 4        Alarije / Alarijen
#
#                                         All Synonyms   Country of origin  \
# 0                            Aldemina, Elmer Swenson                 USA
# 1                                            Odoacra               Italy
# 2  Aidani, Aspro, Aedano, Aedani, Aidano, Aspedan...  Greece (Santorini)
# 3  Aiden, Blancon, Forcallada, Forcallat, Forcall...               Spain
# 4                                                NaN               Spain
#
#         Pedigree Hectares cultivated (Year)  \
# 0  Elmer Swenson                        NaN
# 1            NaN                        NaN
# 2            NaN                        NaN
# 3            NaN             252,000 (2010)
# 4            NaN                        NaN
#
#                            Year of introduction
# ...

# %%
grapes2 = pd.read_csv('grapes/grapes_2.csv')

# %%
#join all 3 dataframes into one
frames = [grapes, grapes1, grapes2]

allgrapes = pd.concat(frames)

# %%
allgrapes
# Out:
#                                         Common Name(s)  \
# 0                                              Abbuoto
# 1                                             Abouriou
# 2                                        Alexandroouli
# 3                                            Akhasheni
# 4                                              Abrusco
# 5                                               Acolon
# 6                                           Ada Karasi
# 7                                          Affenthaler
# 8                                          Agiorgitiko
# 9                                            Aglianico
# 10                                         Aglianicone
# 11                                   Agni (grape) [cs]
# 12                                          Agronomica
# 13                                          Agua Santa
# 14                                        Aidani Mavro
# 15                                          Aladasturi
# ...

# %%
#rename columns for ease of programing
allgrapes.rename(columns={'Common Name(s)': 'Name', 'All Synonyms': 'Synonyms', 'Country of origin': 'Origin'}, inplace=True)

# %%
#Some of the origins have too much information, so I only want things before the comma, 
#here I seperate by comma, and then drop what I don't need
df=pd.concat([allgrapes,allgrapes.Origin.str.split(',',expand=True)],1)
df
# Out:
#                                                   Name  \
# 0                                              Abbuoto
# 1                                             Abouriou
# 2                                        Alexandroouli
# 3                                            Akhasheni
# 4                                              Abrusco
# 5                                               Acolon
# 6                                           Ada Karasi
# 7                                          Affenthaler
# 8                                          Agiorgitiko
# 9                                            Aglianico
# 10                                         Aglianicone
# 11                                   Agni (grape) [cs]
# 12                                          Agronomica
# 13                                          Agua Santa
# 14                                        Aidani Mavro
# 15                                          Aladasturi
# ...

# %%
columns = ['Origin', 'Pedigree', 'Hectares cultivated (Year)', 'Year of introduction', 1, 2, 3]
df.drop(columns, inplace=True, axis=1)

# %%
df.head()
# Out:
#             Name                                           Synonyms  \
# 0        Abbuoto                                     Aboto, Cecubo.
# 1       Abouriou  Beaujolais, Early Burgunder, Early Burgundy, G...
# 2  Alexandroouli  Aleksandroouly, Aleksandrouli, Aleksandrouli s...
# 3      Akhasheni                                        Akhashenuli
# 4        Abrusco  Abrostalo, Abrostine, Abrostino, Abrusco nero,...
#
#                         0
# 0                   Italy
# 1                  France
# 2                 Georgia
# 3  Georgia Eastern parts.
# 4                   Italy

# %%
df.rename(columns={0: 'Origin'}, inplace=True)

# %%
df.head()
# Out:
#             Name                                           Synonyms  \
# 0        Abbuoto                                     Aboto, Cecubo.
# 1       Abouriou  Beaujolais, Early Burgunder, Early Burgundy, G...
# 2  Alexandroouli  Aleksandroouly, Aleksandrouli, Aleksandrouli s...
# 3      Akhasheni                                        Akhashenuli
# 4        Abrusco  Abrostalo, Abrostine, Abrostino, Abrusco nero,...
#
#                    Origin
# 0                   Italy
# 1                  France
# 2                 Georgia
# 3  Georgia Eastern parts.
# 4                   Italy

# %%
#I want to look at just the french grapes
france = df[df.Origin == 'France']

# %%
france.head()
# Out:
#                        Name  \
# 1                  Abouriou
# 22  Alicante Henri Bouschet
# 29              Aramon Noir
# 33                Arinarnoa
# 36                  Arrouya
#
#                                              Synonyms  Origin
# 1   Beaujolais, Early Burgunder, Early Burgundy, G...  France
# 22  Alicant de pays, Alicante, Alicante bouchet, A...  France
# 29  Amor Nao Me Deixes, Aramon, Aramon Chernyi, Ar...  France
# 33                                                NaN  France
# 36  Arhuya, Aroyat, Arrouyat, Arroya, Arruya, Dour...  France

# %%
france1 = france['Name'].str.split('/', expand=True)
france1.head()
# Out:
#                           0     1     2     3     4     5
# 1                  Abouriou  None  None  None  None  None
# 22  Alicante Henri Bouschet  None  None  None  None  None
# 29              Aramon Noir  None  None  None  None  None
# 33                Arinarnoa  None  None  None  None  None
# 36                  Arrouya  None  None  None  None  None

# %%
#make an array of all French grapes
s = france[['Synonyms']].values

# %%
s
# Out:
# array([['Beaujolais, Early Burgunder, Early Burgundy, Gamay Beaujolais, Gamay du Rhône, Gamay St-Laurent, Malbec Argente Negret de la Canourgue, Noir Hatif, Plant Abouriou, Plant Précoce, Précoce Naugé, Précoce Noir, Pressac de Bourgogne.'],
# ...

# %%
import numpy as np

# %%
mylist = s.tolist()
mylist
# Out:
# [['Beaujolais, Early Burgunder, Early Burgundy, Gamay Beaujolais, Gamay du Rhône, Gamay St-Laurent, Malbec Argente Negret de la Canourgue, Noir Hatif, Plant Abouriou, Plant Précoce, Précoce Naugé, Précoce Noir, Pressac de Bourgogne.'],
# ...

# %%
flat_list = [item for sublist in mylist for item in sublist]

# %%
flat_list
# Out:
# ['Beaujolais, Early Burgunder, Early Burgundy, Gamay Beaujolais, Gamay du Rhône, Gamay St-Laurent, Malbec Argente Negret de la Canourgue, Noir Hatif, Plant Abouriou, Plant Précoce, Précoce Naugé, Précoce Noir, Pressac de Bourgogne.',
# ...

# %%
cleanedList = [x for x in flat_list if str(x) != 'nan']

# %%
cleanedList
# Out:
# ['Beaujolais, Early Burgunder, Early Burgundy, Gamay Beaujolais, Gamay du Rhône, Gamay St-Laurent, Malbec Argente Negret de la Canourgue, Noir Hatif, Plant Abouriou, Plant Précoce, Précoce Naugé, Précoce Noir, Pressac de Bourgogne.',
# ...

# %%
list1 = []
for i in cleanedList:
    list1.append(i.split(','))
list1
# Out:
# [['Beaujolais',
#   ' Early Burgunder',
#   ' Early Burgundy',
#   ' Gamay Beaujolais',
#   ' Gamay du Rhône',
#   ' Gamay St-Laurent',
#   ' Malbec Argente Negret de la Canourgue',
#   ' Noir Hatif',
#   ' Plant Abouriou',
#   ' Plant Précoce',
#   ' Précoce Naugé',
#   ' Précoce Noir',
#   ' Pressac de Bourgogne.'],
#  ['Alicant de pays',
#   ' Alicante',
#   ' Alicante bouchet',
#   ' Alicante bouschet',
#   ' Alicante bouschet crni',
#   ' Alicante extra fertile',
#   ' Alicante femminello',
#   ' Alicanteh Bouschet',
#   ' Alicante nero',
#   ' Alicante noir',
#   ' Alicantina',
#   ' Alikant buse',
#   ' Alikant',
#   ' Buse bojadiser',
#   ' Alikant bushe',
#   ' Alikant bushe ekstrafertil',
#   ' Alikant genri bushe',
#   ' Alikante henri bouschet',
#   ' Aragonais',
#   ' Aragones',
#   ' Arrenaou',
#   ' Baga',
#   ' Bakir uezuemue',
#   ' Barvarica',
#   ' Blasco',
#   ' Bojadiserka',
#   ' Carignan jaune',
#   ' Cupper grape',
#   ' Dalmatinka',
#   ' Garnacha',
# ...

# %%
#Now do the same thing to get the Names

# %%
s1 = france1[[0,1,2,3,4,5]].values

# %%
s1
# Out:
# array([['Abouriou', None, None, None, None, None],
#        ['Alicante Henri Bouschet', None, None, None, None, None],
#        ['Aramon Noir', None, None, None, None, None],
#        ['Arinarnoa', None, None, None, None, None],
#        ['Arrouya', None, None, None, None, None],
#        ['Aspiran Bouschet', None, None, None, None, None],
#        ['Aspiran Noir', None, None, None, None, None],
#        ['Aubun', None, None, None, None, None],
#        ['Bachet Noir', None, None, None, None, None],
#        ['Baco Noir', None, None, None, None, None],
#        ['Beaunoir', None, None, None, None, None],
#        ['Béclan', None, None, None, None, None],
#        ['Béquignol Noir', None, None, None, None, None],
#        ['Blauer Arbst ', ' Pinot Noir', None, None, None, None],
#        ['Bouchalès', None, None, None, None, None],
#        ['Bourrisquou', None, None, None, None, None],
#        ['Braquet Noir', None, None, None, None, None],
# ...

# %%
mylist1 = s1.tolist()
mylist1
# Out:
# [['Abouriou', None, None, None, None, None],
#  ['Alicante Henri Bouschet', None, None, None, None, None],
#  ['Aramon Noir', None, None, None, None, None],
#  ['Arinarnoa', None, None, None, None, None],
#  ['Arrouya', None, None, None, None, None],
#  ['Aspiran Bouschet', None, None, None, None, None],
#  ['Aspiran Noir', None, None, None, None, None],
#  ['Aubun', None, None, None, None, None],
#  ['Bachet Noir', None, None, None, None, None],
#  ['Baco Noir', None, None, None, None, None],
#  ['Beaunoir', None, None, None, None, None],
#  ['Béclan', None, None, None, None, None],
#  ['Béquignol Noir', None, None, None, None, None],
#  ['Blauer Arbst ', ' Pinot Noir', None, None, None, None],
#  ['Bouchalès', None, None, None, None, None],
#  ['Bourrisquou', None, None, None, None, None],
#  ['Braquet Noir', None, None, None, None, None],
#  ['Brun Argenté', None, None, None, None, None],
#  ['Brun Fourca', None, None, None, None, None],
# ...

# %%
flat_list1 = [item for sublist in mylist1 for item in sublist]

# %%
flat_list1
# Out:
# ['Abouriou',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Alicante Henri Bouschet',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Aramon Noir',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Arinarnoa',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Arrouya',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Aspiran Bouschet',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Aspiran Noir',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Aubun',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Bachet Noir',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Baco Noir',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Beaunoir',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Béclan',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Béquignol Noir',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Blauer Arbst ',
#  ' Pinot Noir',
#  None,
#  None,
#  None,
#  None,
#  'Bouchalès',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Bourrisquou',
#  None,
#  None,
#  None,
# ...

# %%
cleanedList1 = [x for x in flat_list1 if str(x) != 'None']

# %%
cleanedList1
# Out:
# ['Abouriou',
#  'Alicante Henri Bouschet',
#  'Aramon Noir',
#  'Arinarnoa',
#  'Arrouya',
#  'Aspiran Bouschet',
#  'Aspiran Noir',
#  'Aubun',
#  'Bachet Noir',
#  'Baco Noir',
#  'Beaunoir',
#  'Béclan',
#  'Béquignol Noir',
#  'Blauer Arbst ',
#  ' Pinot Noir',
#  'Bouchalès',
#  'Bourrisquou',
#  'Braquet Noir',
#  'Brun Argenté',
#  'Brun Fourca',
#  'Cabernet Franc',
#  'Cabernet Gernischt',
#  'Cabernet Sauvignon',
#  'Caladoc',
#  'Calitor Noir',
#  'Camaraou Noir',
#  'Camarese',
#  'Canari Noir',
#  'Carinena',
#  'Carménère',
#  'Cascade',
#  'Castets',
#  'César',
#  'Chambourcin',
#  'Charbono',
#  'Chancellor',
#  'Chatus',
#  'Chelois',
#  'Chenanson',
#  'Chichaud',
#  'Cinsaut',
#  'Counoise',
#  'Douce noir',
#  'Charbono',
#  'Bonarda',
#  'Turca',
#  'Douce Noire grise',
#  'Duras',
#  'Dureza',
#  'Durif ',
#  ' Petite Sirah',
#  'Ederena',
#  'Enfariné noir',
#  'Étraire',
#  'Fer',
#  'Gamay ',
#  ' Gamay noir',
#  'Gouget noir',
# ...

# %%
frenchGrapes = cleanedList1 + list1

# %%
frenchGrapes
# Out:
# ['Abouriou',
#  'Alicante Henri Bouschet',
#  'Aramon Noir',
#  'Arinarnoa',
#  'Arrouya',
#  'Aspiran Bouschet',
#  'Aspiran Noir',
#  'Aubun',
#  'Bachet Noir',
#  'Baco Noir',
#  'Beaunoir',
#  'Béclan',
#  'Béquignol Noir',
#  'Blauer Arbst ',
#  ' Pinot Noir',
#  'Bouchalès',
#  'Bourrisquou',
#  'Braquet Noir',
#  'Brun Argenté',
#  'Brun Fourca',
#  'Cabernet Franc',
#  'Cabernet Gernischt',
#  'Cabernet Sauvignon',
#  'Caladoc',
#  'Calitor Noir',
#  'Camaraou Noir',
#  'Camarese',
#  'Canari Noir',
#  'Carinena',
#  'Carménère',
#  'Cascade',
#  'Castets',
#  'César',
#  'Chambourcin',
#  'Charbono',
#  'Chancellor',
#  'Chatus',
#  'Chelois',
#  'Chenanson',
#  'Chichaud',
#  'Cinsaut',
#  'Counoise',
#  'Douce noir',
#  'Charbono',
#  'Bonarda',
#  'Turca',
#  'Douce Noire grise',
#  'Duras',
#  'Dureza',
#  'Durif ',
#  ' Petite Sirah',
#  'Ederena',
#  'Enfariné noir',
#  'Étraire',
#  'Fer',
#  'Gamay ',
#  ' Gamay noir',
#  'Gouget noir',
# ...

# %%
len(frenchGrapes)
# Out:
# 322

# %%
grapes_ = 0
lists_ = 0

l1 = []

for element in frenchGrapes:
    if type(element) == str:
        l1.append(element)
        grapes_ += 1
    else:
        l1 += element
        lists_ += 1
print(grapes_, lists_)
# Out:
# 224 98

# %%
len(l1)
# Out:
# 2864

# %%
#strip the white space out
all_french_grapes = [i.strip() for i in l1]

# %%
all_french_grapes
# Out:
# ['Abouriou',
#  'Alicante Henri Bouschet',
#  'Aramon Noir',
#  'Arinarnoa',
#  'Arrouya',
#  'Aspiran Bouschet',
#  'Aspiran Noir',
#  'Aubun',
#  'Bachet Noir',
#  'Baco Noir',
#  'Beaunoir',
#  'Béclan',
#  'Béquignol Noir',
#  'Blauer Arbst',
#  'Pinot Noir',
#  'Bouchalès',
#  'Bourrisquou',
#  'Braquet Noir',
#  'Brun Argenté',
#  'Brun Fourca',
#  'Cabernet Franc',
#  'Cabernet Gernischt',
#  'Cabernet Sauvignon',
#  'Caladoc',
#  'Calitor Noir',
#  'Camaraou Noir',
#  'Camarese',
#  'Canari Noir',
#  'Carinena',
#  'Carménère',
#  'Cascade',
#  'Castets',
#  'César',
#  'Chambourcin',
#  'Charbono',
#  'Chancellor',
#  'Chatus',
#  'Chelois',
#  'Chenanson',
#  'Chichaud',
#  'Cinsaut',
#  'Counoise',
#  'Douce noir',
#  'Charbono',
#  'Bonarda',
#  'Turca',
#  'Douce Noire grise',
#  'Duras',
#  'Dureza',
#  'Durif',
#  'Petite Sirah',
#  'Ederena',
#  'Enfariné noir',
#  'Étraire',
#  'Fer',
#  'Gamay',
#  'Gamay noir',
#  'Gouget noir',
#  'Grand noir de la Calmette',
# ...

# %%
#grapes to take out of french grapes
notfrench = ['Gewürztraminer', 'Riesling', 'Gewürztraminer-Riesling', 'White Riesling','Monastrell', 'Chardonnay Weissburgunder', 'Spätburgunder']

# %%
#take out notfrench from all_french_grapes
french_grapes2 = [x for x in all_french_grapes if x not in notfrench]

# %%
len(french_grapes2)
# Out:
# 2861

# %%
#grape blends to add into french grapes
french_blends = ['Meritage', 'Bordeaux-style Red Blend', 'Rhône-style Red Blend', 'Bordeaux-style White Blend', 
 'Shiraz-Cabernet Sauvignon', 'Cabernet Sauvignon-Syrah','Merlot-Malbec','Chenin Blanc-Chardonnay',
 'Cabernet Sauvignon-Merlot','Sauvignon Blanc-Semillon','Malbec-Merlot','Malbec-Cabernet Franc',
 'Cabernet Sauvignon-Shiraz','Syrah-Cabernet Sauvignon','Cabernet Franc-Cabernet Sauvignon','Merlot-Cabernet Franc', 
 'Syrah-Petite Sirah', 'Cabernet Blend','Malbec-Cabernet Sauvignon','Cabernet Sauvignon-Malbec','Syrah-Petit Verdot',
 'Malbec-Syrah','Cabernet-Syrah', 'Sauvignon Blanc-Chardonnay','Merlot-Cabernet Sauvignon',
 'Chenin Blanc-Sauvignon Blanc','Chardonnay-Sauvignon Blanc','Cabernet Sauvignon-Cabernet Franc',
 'Chardonnay-Sauvignon','Pinot-Chardonnay','Merlot-Cabernet','Shiraz-Cabernet','Sauvignon Blanc-Chenin Blanc', 
 'Malbec-Petit Verdot','Chardonnay-Pinot Gris', 'Chardonnay-Pinot Blanc','Cabernet Sauvignon-Merlot-Shiraz', 
 'Malbec-Cabernet', 'Carmenère-Syrah', 'Pinot Blanc-Pinot Noir', 'Shiraz-Malbec', 'Syrah-Malbec', 
 'Syrah-Cabernet Franc','Cabernet-Shiraz', 'Pinot Blanc-Chardonnay', 'Merlot-Shiraz', 'Merlot-Syrah', 
 'Sauvignon Blanc-Sauvignon Gris', 'Cabernet-Malbec', 'Merlot-Petite Verdot', 'Cabernet Merlot', 'Chenin Blanc', 
'Pinot Noir-Gamay', 'Carmenère-Cabernet Sauvignon', 'Viognier-Valdiguié', 'Pinot Grigio-Sauvignon Blanc', 
'Pinot Blanc-Viognier', 'Shiraz-Roussanne', 'Shiraz-Roussanne', 'Pinot Noir-Syrah', 'Malbec-Carménère', 
'Semillon-Chardonnay', 'Sauvignon-Sémillon', 'Chenin Blanc-Viognier', 'Cabernet Sauvignon-Carmenère', 
'Viognier-Roussanne', 'Merlot-Tannat', 'Petite Verdot', 'Colombard-Sauvignon Blanc', 'Alicante Bouschet', 
'Chardonnay-Semillon', 'Syrah-Merlot', 'Cabernet Franc-Merlot', 'Seyval Blanc', 'Roussanne-Viognier', 
'Sauvignon Gris', 'Gamay Noir', 'Cabernet Franc-Carmenère', 'Chardonnay-Viognier', 'Syrah-Cabernet', 
'Marsanne-Viognier', 'Claret', 'Semillon-Sauvignon Blanc', 'Malbec-Tannat', 'Pinot Nero',
'Champagne Blend', 'Pinot Grigio', 'Carmenère', 'Sauvignon Blanc', 'Viognier', 'Viognier-Chardonnay', 
'Alsace white blend', 'Pinot Blanc', 'Fumé Blanc', 'Syrah-Viognier',  'Shiraz-Viognier','Rhône-style White Blend' ]

# %%
#add in the grape blends to french grapes
frenchvariety = french_grapes2 + french_blends

# %%
#make a new column in the df where if the grape variety is french, french_grape = True, if not then False
wine['french_grape'] = wine['variety'].apply(lambda x: x in frenchvariety)

# %%
wine.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery  french_grape
# 0     White Blend              Nicosia         False
# 1  Portuguese Red  Quinta dos Avidagos         False

# %%
frenchwine = wine['french_grape'] == True

# %%
wine[frenchwine].variety.unique()
# Out:
# array(['Pinot Gris', 'Pinot Noir', 'Cabernet Sauvignon', 'Chardonnay',
#        'Malbec', 'Meritage', 'Merlot', 'Chenin Blanc', 'Gamay',
#        'Sauvignon Blanc', 'Viognier-Chardonnay', 'Petit Verdot',
#        'Bordeaux-style White Blend', 'Cabernet Franc', 'Champagne Blend',
#        'Bordeaux-style Red Blend', 'Petite Sirah', 'Carmenère',
#        'Petit Manseng', 'Viognier', 'Syrah', 'Shiraz-Cabernet Sauvignon',
#        'Pinot Blanc', 'Alsace white blend', 'Rhône-style Red Blend',
#        'Sauvignon', 'Fumé Blanc', 'Bonarda', 'Shiraz', 'Syrah-Viognier',
#        'Savagnin', 'Cabernet Sauvignon-Syrah', 'Shiraz-Viognier',
#        'Pinot Grigio', 'Melon', 'Rhône-style White Blend', 'Marsanne',
#        'Pinot Nero', 'Sémillon', 'Pinot Noir-Gamay',
#        'Cabernet Sauvignon-Carmenère', 'Colombard', 'Roussanne',
#        'Cinsault', 'Chenin Blanc-Chardonnay', 'Merlot-Malbec',
#        'Cabernet Sauvignon-Merlot', 'Duras', 'Traminer', 'Charbono',
# ...

# %%
wine[frenchwine].variety.unique().shape
# Out:
# (169,)

# %%
notfrenchwine = wine['french_grape'] == False

# %%
wine[notfrenchwine].variety.unique()
# Out:
# array(['White Blend', 'Portuguese Red', 'Riesling', 'Tempranillo-Merlot',
#        'Frappato', 'Gewürztraminer', 'Nerello Mascalese',
#        'Tempranillo Blend', 'Red Blend', "Nero d'Avola", 'Primitivo',
#        'Catarratto', 'Inzolia', 'Monica', 'Grillo', 'Sangiovese',
#        'Aglianico', 'Touriga Nacional', 'Albariño', 'Rosé', 'Zinfandel',
#        'Vernaccia', 'Rosato', 'Grüner Veltliner', 'Vermentino',
#        'Grenache Blanc', 'Nebbiolo', 'Barbera', 'Portuguese White',
#        'Graciano', 'Tannat-Cabernet', 'Sangiovese Grosso', 'Torrontés',
#        'Prugnolo Gentile', 'G-S-M', 'Verdejo', 'Furmint', 'Pinot Bianco',
#        'Montepulciano', 'Moscato', 'Grenache', 'Ugni Blanc-Colombard',
#        'Blaufränkisch', 'Friulano', 'Assyrtico', 'Carignan-Grenache',
#        'Sagrantino', 'Prosecco', 'Vignoles', 'Sparkling Blend', 'Muscat',
#        'Muscadelle', 'Garganega', 'Tempranillo', 'Zierfandler', 'Cortese',
# ...

# %%
wine[notfrenchwine].variety.unique().shape
# Out:
# (539,)

# %%
#save file to csv
wine.to_csv('wine_reviews.csv', index=False)
